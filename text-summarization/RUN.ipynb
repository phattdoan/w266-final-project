# %%
import time

t0 = time.time()
# %run demo/seq2seq_train.py
t1 = time.time()

total = t1-t0
print (total)
# Out:
# loading csv file ...
# extract configuration from input texts ...
# demo size:  5068
# testing size:  1267
# start fitting ...
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/topology.py:2368: UserWarning: Layer decoder_lstm was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'encoder_lstm_2/while/Exit_2:0' shape=(?, 100) dtype=float32>, <tf.Tensor 'encoder_lstm_2/while/Exit_3:0' shape=(?, 100) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '
# (5068,)
# (1267,)
# (5068, 500)
# (1267, 500)
# Epoch 1/100
# 79/79 [==============================] - 80s 1s/step - loss: 1.0850 - acc: 0.0209 - val_loss: 1.0315 - val_acc: 0.0222
# Epoch 2/100
# 79/79 [==============================] - 79s 1s/step - loss: 1.0400 - acc: 0.0241 - val_loss: 1.0257 - val_acc: 0.0223
# Epoch 3/100
# ...

# %%
import time

t0 = time.time()
# %run demo/seq2seq_predict.py
t1 = time.time()

total = t1-t0
print (total)
# Out:
# loading csv file ...
# start predicting ...
# Generated Headline:  the u.s. of america in us election
# Original Headline:  The Wild Ideas You Missed While Donald Trump Was Talking
# Generated Headline:  global warming between house — lawmakers on immigration deal
# Original Headline:  Live from New Hampshire: They’re all here
# Generated Headline:  comment on china have no when when when asked about how the people by this this time
# Original Headline:  UK Child Protection Services workers are ‘afraid’ to challenge the ages of Muslim invaders for fear of ending up in court
# Generated Headline:  trump camp up up to block against trump of hillary
# Original Headline:  Desperate Trump Supporter Offers Voters Discount On Horse Semen If They Vote Trump
# Generated Headline:  comment on if you want what trump want by hillary clinton email investigation by the economy by russia has you
# ...
