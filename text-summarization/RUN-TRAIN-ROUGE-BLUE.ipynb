# %%
import time

t0 = time.time()
# %run demo/seq2seq_predict.py
t1 = time.time()

total = t1-t0
print (total)
# Out:
# loading csv file ...
# start predicting ...
# Example: 1542
# Generated Headline:  the media of the debate but a good
# Original Headline:  The Wild Ideas You Missed While Donald Trump Was Talking
# BLUE score: 0
# ----------------------------------------------------------------
# Example: 4037
# Generated Headline:  obama says he was hillary’s chicago ahead of hillary clinton in wikileaks
# Original Headline:  Live from New Hampshire: They’re all here
# BLUE score: 0
# ----------------------------------------------------------------
# Example: 3644
# Generated Headline:  the united states is more than in syria for her in muslim
# Original Headline:  UK Child Protection Services workers are ‘afraid’ to challenge the ages of Muslim invaders for fear of ending up in court
# BLUE score: 0.33401359264888447
# ----------------------------------------------------------------
# c:\users\phatt\appdata\local\continuum\anaconda3\lib\site-packages\nltk\translate\bleu_score.py:490: UserWarning:
# ...
