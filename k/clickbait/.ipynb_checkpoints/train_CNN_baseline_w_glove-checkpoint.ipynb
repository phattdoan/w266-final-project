# %%
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install s3fs

# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
# import cPickle
from collections import defaultdict
import re
import sys
import os

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn import preprocessing

import keras
from keras.utils import np_utils
from keras.layers import Conv1D, MaxPooling1D, Embedding, Merge
from keras.layers import Input, Dense, Activation, Embedding, Conv2D, MaxPool2D
from keras.layers import Reshape, Flatten, Dropout, Concatenate
from keras.models import Model, Sequential
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

from sklearn.model_selection import train_test_split

import s3fs

import time
import datetime
from data_helpers_v8 import load_data, clean_str, text_preprocessing, label_processing, evaluation, ints2setences
from tensorflow.contrib import learn
import tensorflow as tf
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\users\phatt\appdata\local\continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# data preparation --------------------------------------------

URL1 = 's3://smart-newsdev-dmp/tmp/data/classification/clickbait_data'
URL2 = 's3://smart-newsdev-dmp/tmp/data/classification/non_clickbait_data'

import pandas as pd
df1 = pd.read_csv(URL1, sep="\n", names=['title'])
df2 = pd.read_csv(URL2, sep="\n", names=['title'])

df1['category'] = 1
df2['category'] = 0

data = pd.concat([df1, df2])

data = data.sample(frac=1).reset_index(drop=True)

data['idx'] = data.index
data['idx'] = data['idx'].map(int)

from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2, random_state=42)

train.to_csv('train.csv', sep='|', index = False)
test.to_csv('test.csv', sep='|', index = False)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# c:\users\phatt\appdata\local\continuum\anaconda3\lib\site-packages\pandas\io\s3.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#      24     try:
# ---> 25         filepath_or_buffer = fs.open(_strip_schema(filepath_or_buffer))
#      26     except (OSError, NoCredentialsError):
#
# c:\users\phatt\appdata\local\continuum\anaconda3\lib\site-packages\s3fs\core.py in open(self, path, mode, block_size, acl, fill_cache, **kwargs)
#     298         return S3File(self, path, mode, block_size=block_size, acl=acl,
# --> 299                       fill_cache=fill_cache, s3_additional_kwargs=kw)
#     300
#
# c:\users\phatt\appdata\local\continuum\anaconda3\lib\site-packages\s3fs\core.py in __init__(self, s3, path, mode, block_size, acl, fill_cache, s3_additional_kwargs)
#    1016             try:
# ...

# %%
MAX_LEN_DOC = 20
MAX_NB_WORDS = 200000
URL1 = 'train.csv'
URL2 = 'test.csv'
URL3 = 's3://smart-newsdev-dmp/tmp/data/classification/data_handlabeling_cycle1/test.csv'
TEXT_TITLE_COMBINED = False

x, y, split_index, vocab_size, id2word, word2id, pre_x, pre_data, additional_title = load_data(
    MAX_LEN_DOC=MAX_LEN_DOC, MAX_NB_WORDS=MAX_NB_WORDS,
    url1=URL1, url2=URL2, url3=URL3, TEXT_TITLE_COMBINED=TEXT_TITLE_COMBINED)

pre_x_train, pre_x_test = pre_x.iloc[0:split_index], pre_x.iloc[split_index:]
x_train, x_test, y_train, y_test = x[0:split_index], x[split_index:], y[0:split_index], y[split_index:]

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Loading data...
# Clean up texts...
# Tokenizing...
# Integer encoding...
# Padding...
# ('x_train shape:', (25600, 20))
# ('x_test shape:', (6400, 20))

# %%
embeddings_index = {}
f = open('../word_vector/glove.6B.100d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
# parameters --------------------------------------------------

sequence_length = x_train.shape[1]
vocabulary_size = vocab_size
filter_sizes = [3,4,5]
num_filters = 512
drop = 0.5
num_class = y_train.shape[1]
embedding_dim = 100
epochs = 5
batch_size = 32
# --------------------------------------------------------------

print("Creating Model...")
# TO DO --- store the model in function

embedding_matrix = np.zeros((len(word2id) + 1, embedding_dim))
for word, i in word2id.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

inputs = Input(shape=(sequence_length,), dtype='int32')
embedding = Embedding(input_dim=vocabulary_size, 
                      output_dim=embedding_dim,
                      weights = [embedding_matrix], #### use pre-trained word vector
                      trainable = False,  #### use pre-trained word vector
                      input_length=sequence_length)(inputs)
reshape = Reshape((sequence_length,embedding_dim,1))(embedding)

conv_0 = Conv2D(num_filters, kernel_size=(filter_sizes[0], embedding_dim), padding='valid', kernel_initializer='normal', activation='relu')(reshape)
conv_1 = Conv2D(num_filters, kernel_size=(filter_sizes[1], embedding_dim), padding='valid', kernel_initializer='normal', activation='relu')(reshape)
conv_2 = Conv2D(num_filters, kernel_size=(filter_sizes[2], embedding_dim), padding='valid', kernel_initializer='normal', activation='relu')(reshape)

maxpool_0 = MaxPool2D(pool_size=(sequence_length - filter_sizes[0] + 1, 1), strides=(1,1), padding='valid')(conv_0)
maxpool_1 = MaxPool2D(pool_size=(sequence_length - filter_sizes[1] + 1, 1), strides=(1,1), padding='valid')(conv_1)
maxpool_2 = MaxPool2D(pool_size=(sequence_length - filter_sizes[2] + 1, 1), strides=(1,1), padding='valid')(conv_2)

concatenated_tensor = Concatenate(axis=1)([maxpool_0, maxpool_1, maxpool_2])
flatten = Flatten()(concatenated_tensor)
dropout = Dropout(drop)(flatten)
output = Dense(units=num_class, activation='sigmoid')(dropout)

# this creates a model that includes
model = Model(inputs=inputs, outputs=output)

adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0001)

model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
# try categorical_crossentropy?

print("Traning Model...")
history = model.fit(x_train, y_train, 
          batch_size=batch_size, epochs=epochs, verbose=1, validation_split=0.1)
# should have store this in history
# https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
# Out:
# Creating Model...
# Traning Model...
# Train on 23040 samples, validate on 2560 samples
# Epoch 1/5
# 23040/23040 [==============================] - 36s 2ms/step - loss: 0.2622 - acc: 0.8858 - val_loss: 0.1505 - val_acc: 0.9439
# Epoch 2/5
# 23040/23040 [==============================] - 36s 2ms/step - loss: 0.1516 - acc: 0.9398 - val_loss: 0.1253 - val_acc: 0.9553
# Epoch 3/5
# 23040/23040 [==============================] - 36s 2ms/step - loss: 0.1173 - acc: 0.9554 - val_loss: 0.1128 - val_acc: 0.9590
# Epoch 4/5
# 23040/23040 [==============================] - 36s 2ms/step - loss: 0.1020 - acc: 0.9620 - val_loss: 0.1024 - val_acc: 0.9598
# Epoch 5/5
# 23040/23040 [==============================] - 36s 2ms/step - loss: 0.0876 - acc: 0.9675 - val_loss: 0.0969 - val_acc: 0.9615

# %%
# evaluate the model
scores = model.evaluate(x_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# acc: 96.43%

# %%
def check_sample(pre_x, post_x, sampl_num, id2word):
    print ('\n{} Original x_text #{} {}\n'.format('---'*10, sampl_num,'---'*10))
    print (pre_x.iloc[sampl_num])
#     print ('\n{} Original title #{} {}\n'.format('---'*10, sampl_num,'---'*10))
#     print (pre_df['title'].iloc[sampl_num])
#     print ('\n{} Original text #{} {}\n'.format('---'*10, sampl_num,'---'*10))
#     print (pre_df['text'].iloc[sampl_num])
#     print ('\n{} Processed x_text #{} {}\n'.format('---'*10, sampl_num,'---'*10))
#     print (post_x[sampl_num])
    print ('\n{} Reverted x_text #{} {}\n'.format('---'*10, sampl_num,'---'*10))
    print (ints2setences(post_x[sampl_num], id2word))

def error_analysis(y_pred, y_test, pre_x, post_x, id2word, num_errors):
    for item in np.where(y_pred != y_test):
        for i, idx in enumerate (item):
            if i < num_errors:
                print("----------------------------idx {}, prediction {}, test {} ----------------------------------".format(
                    idx, y_pred[idx], y_test[idx]))
                print ("prediction----{}".format(y_pred[idx]))
                print ("test----------{}".format(y_test[idx]))
                print("---"*30)
                print (check_sample(pre_x=pre_x, post_x=post_x, sampl_num=idx, id2word=id2word))

# %%
y_pred = model.predict(x_test)
evaluation(y_pred=y_pred.argmax(-1), y_test=y_test.argmax(-1), history=history)
error_analysis(y_pred.argmax(-1), y_test.argmax(-1), pre_x_test, x_test, id2word, 30)
# Out:
# ---------Confusion Matrix Report --------------------
#
# [[3097   97]
#  [ 130 3076]]
#
# ---------Classificaiton Report ----------------------
#
#              precision    recall  f1-score   support
#
#           0       0.96      0.97      0.96      3194
#           1       0.97      0.96      0.96      3206
#
# avg / total       0.96      0.96      0.96      6400
#
# ['acc', 'loss', 'val_acc', 'val_loss']
# ----------------------------idx 10, prediction 1, test 0 ----------------------------------
# prediction----1
# test----------0
# ------------------------------------------------------------------------------------------
#
# ------------------------------ Original x_text #10 ------------------------------
#
# 2 Ex-Timesmen Say They Had a Tip on Watergate First
#
# ------------------------------ Reverted x_text #10 ------------------------------
#
# 2 ex say they had a tip on watergate first
# None
# ...

# %%
y_pred = model.predict(additional_title)

# %%
y_pred.shape
# Out:
# (1971, 2)

# %%
y_pred
# Out:
# array([[  2.02214435e-01,   7.99830675e-01],
#        [  1.73282281e-01,   8.72296631e-01],
#        [  9.94643927e-01,   5.33291604e-03],
#        ...,
#        [  9.99190629e-01,   8.79560073e-04],
#        [  1.80690378e-01,   8.88697445e-01],
#        [  9.74407971e-01,   3.40665020e-02]], dtype=float32)

# %%
y_pred[:,1].shape
# Out:
# (1971,)

# %%
y_pred.argmax(-1)
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
temp = pd.read_csv(URL3, sep='|')

temp.head()

# %%
def show_results(df_original, prediction):
    
    prediction = pd.DataFrame(prediction[:,1], columns= ['clickbait_score'])
    
    df_original = pd.concat([df_original, prediction], axis=1)
    
    df_original = df_original.sort_values(by=['clickbait_score','category'], ascending=False)
    
    df_original = df_original.loc[:,['title','category','clickbait_score']]
    
    return df_original

test = show_results(temp, y_pred)

# %%
pd.set_option('display.max_colwidth', -1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

test.clickbait_score.hist(bins=50)

# %%
test.clickbait_score.describe()
# Out:
# count    1971.000000
# mean        0.281861
# std         0.352256
# min         0.000027
# 25%         0.007039
# 50%         0.078513
# 75%         0.543213
# max         0.999997
# Name: clickbait_score, dtype: float64

# %%
test.groupby(['category']).agg(['mean','count'])
# Out:
#                     clickbait_score
#                                mean count
# category
# EN_US_BUSINESS       0.189788        154
# EN_US_ENTERTAINMENT  0.615294        244
# EN_US_LIFESTYLE      0.673502        149
# EN_US_NATIONAL       0.164110        195
# EN_US_POLITICS       0.173666        236
# EN_US_SCIENCE        0.286988        260
# EN_US_SPORTS         0.159508        280
# EN_US_TECHNOLOGY     0.273244        221
# EN_US_WORLD          0.099931        232

# %%
test[test.clickbait_score > 0.9]
# Out:
#                                                                                                              title  \
# 392   8 Things I Would Love to Give My Kids This Christmas
# 1769  5 Things You Need To Know About Interacting With Me, a Fat Girl Who Wears Revealing Clothes
# 1002  53 Fascinating Facts You Probably Didn't Know About Disney Films
# 242   16 Things You Think He Cares About  But He Really Doesnt
# 1587  16 Adorable Animals Who Are Too Tired To Animal
# 1718  9 Books You Need To Read This Summer
# 353   24 Kids Who Are Wise Beyond Their Years
# 368   Victor Martinez's Sexy Dance Is Very Sexy
# 730   6 Bizarre Side Effects of Foods You Eat Every Day
# 605   5 things you need to know Monday
# 1848  56 Movies Guaranteed To Make You Ugly Cry
# 1182  10 Sriracha Cocktails to Get You Drunk in Spicy Love
# 386   12 Things You Can Only See At Bonnaroo
# 601   I’m A Dude And Here Are 10 Honest Reasons Why I Won’t Date You
# ...

# %%
test[test.category =='EN_US_BUSINESS'][test.clickbait_score > 0.7].drop(['category'],axis=1)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                                                                                                     title  \
# 914   7 Entrepreneurs You Should Start Following Now
# 1036  3 Reasons Why You Shouldn't Focus on Getting a Promotion
# 640   Peter Thiel Wants To Know: 'What Are You Doing That Nobody Else Is Doing?'
# 1112  Gen Z Employees: The 5 Attributes You Need to Know
# 1854  6 Tools To Jump Start Your Video Content Marketing
# 1107  What to Do When Your Employees Aren't Living Up to Expectations
# 590   Why Every Woman Needs A Mentor
# 1948  The Evolution Of The Manager...And What It Means For You
# 269   The Grinch who stole Public Square: editorial
# 1838  Goldman's Blankfein: I'm Sure I'm Paranoid
# 638   Did CNN just call Bloomberg’s ‘Everytown’ group liars?
# ...

# %%
test[test.category =='EN_US_POLITICS'][test.clickbait_score > 0.7].drop(['category'],axis=1)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                                                                                                 title  \
# 467   What Do You Mean, 'Our' Children, Congressman?
# 405   Hillary Clinton Can Joke About Her Scrunchies: Glamour.com
# 427   The One Thing You Need To Stop Doing To Become A Great Communicator
# 528   Political Cartoons - Political Humor, Jokes, and Pictures, Obama, Palin
# 1843  The White House posted its favorite photos from 2014 today. We handed out some superlatives.
# 448   Palin: ‘If Republicans Are Gonna Act Like Democrats, Then What’s the Use?’
# 321   Yes, Ebola Is Scary. But the System Is Working.
# 1790  Oregon Governor John Kitzhaber: How we got here
# 1145  Chris Matthews to Elizabeth Warren: ‘Give me a date’
# ...

# %%
test[test.category =='EN_US_NATIONAL'][test.clickbait_score > 0.7].drop(['category'],axis=1)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                                                                                                                                                                title  \
# 605   5 things you need to know Monday
# 1826  5 Things to Know This Morning - ABC News
# 906   John Grisham: men who watch child porn are not all paedophiles
# 445   Homeowners Set Up Doggy Cam to Watch Family Pet. What They Saw Instead Had Police Rushing to the Scene.
# 1028  Father Charged With Killing the Man Who Molested His Daughter When She Was Only 7 Years Old
# 193   Bride-to-be killed going to her bachelorette party
# 1090  The Worst States to Be a Working Mom - ABC News
# ...
